# %%
pip install line-bot-sdk

# %%
from flask import Flask,request
#https://github.com/line/line-bot-sdk-python
from linebot import LineBotApi,WebhookHandler
from linebot.models import FlexSendMessage,TextSendMessage
token="5pkSnrKNYWiH82Jxc9Z4XxyT+pVmrVfMYiyjY+mDyuADpCrpa4HgmbNEdnFvWqrh2CDkCjbfLUl1O14KDwj6IpuoVfPa+oSU3pbefHzwML+qtKXj5iQ3YiBEsJSfNhW0ckXjRNye6s9ps1hDCMWA7QdB04t89/1O/w1cDnyilFU="
app=Flask(__name__)
# LINE 聊天機器人的基本資料
line_bot=LineBotApi(token)
@app.route("/", methods=['POST'])
def verify():
    data=request.get_json()
    print(data)
    #給Webhook驗證使用
    if(len(data['events'])==0):
        print("webhook驗證通知")
        pass
    else:
        text=data["events"][0]["message"]["text"]
        uid=data["events"][0]["source"]["userId"]
        rptk=data["events"][0]["replyToken"]
        print(text,uid,rptk)
        line_bot.reply_message(rptk,[TextSendMessage(text=text)])
    return 'OK',200
if(__name__ == "__main__"):
    app.run(port=2315)

# %%
from flask import Flask,request
#https://github.com/line/line-bot-sdk-python
from linebot import LineBotApi,WebhookHandler
from linebot.models import FlexSendMessage,TextSendMessage,StickerSendMessage
import json
import requests
import random
import time
token="5pkSnrKNYWiH82Jxc9Z4XxyT+pVmrVfMYiyjY+mDyuADpCrpa4HgmbNEdnFvWqrh2CDkCjbfLUl1O14KDwj6IpuoVfPa+oSU3pbefHzwML+qtKXj5iQ3YiBEsJSfNhW0ckXjRNye6s9ps1hDCMWA7QdB04t89/1O/w1cDnyilFU="
app=Flask(__name__)
# LINE 聊天機器人的基本資料
line_bot=LineBotApi(token)
@app.route("/", methods=['POST'])
def verify():
    data=request.get_json()
    print(data)
    #給Webhook驗證使用
    if(len(data['events'])==0):
        print("webhook驗證通知")
        pass
    else:
        text=data["events"][0]["message"]["text"]
        uid=data["events"][0]["source"]["userId"]
        rptk=data["events"][0]["replyToken"]
        print(text,uid,rptk)
        message=text
        token="JIWQ7gh6DgVFzVQfOUXTRISEYtD1EI89sVQ6J3an8rP"
        h={"Authorization":"Bearer "+token}
        d={'message':message}
        for i in range(0,random.randint(10,10)):
            if(random.randint(1,10)<2):
                requests.post("https://notify-api.line.me/api/notify",headers=h,data=d)
            if(random.randint(1,10)<4):
                line_bot.reply_message(rptk,[TextSendMessage(text=text)])
            time.sleep(5)
    return 'OK',200
if(__name__ == "__main__"):
    app.run(port=2315)

# %%
from flask import Flask,request
#https://github.com/line/line-bot-sdk-python
from linebot import LineBotApi,WebhookHandler
from linebot.models import FlexSendMessage,TextSendMessage,StickerSendMessage
import json
token="5pkSnrKNYWiH82Jxc9Z4XxyT+pVmrVfMYiyjY+mDyuADpCrpa4HgmbNEdnFvWqrh2CDkCjbfLUl1O14KDwj6IpuoVfPa+oSU3pbefHzwML+qtKXj5iQ3YiBEsJSfNhW0ckXjRNye6s9ps1hDCMWA7QdB04t89/1O/w1cDnyilFU="
app=Flask(__name__)
# LINE 聊天機器人的基本資料
line_bot=LineBotApi(token)
@app.route("/", methods=['POST'])
def verify():
    data=request.get_json()
    print(data)
    #給Webhook驗證使用
    if(len(data['events'])==0):
        print("webhook驗證通知")
        pass
    else:
        text=data["events"][0]["message"]["text"]
        uid=data["events"][0]["source"]["userId"]
        rptk=data["events"][0]["replyToken"]
        print(text,uid,rptk)
        line_bot.reply_message(rptk,[FlexSendMessage(alt_text="123",contents={
  "type": "bubble",
  "direction": "ltr",
  "header": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "text",
        "text": "知識",
        "weight": "bold",
        "size": "3xl",
        "align": "center",
        "contents": []
      }
    ]
  },
  "hero": {
    "type": "image",
    "url": "https://i.imgur.com/I2jKwd4.jpg",
    "size": "full",
    "aspectRatio": "1.51:1",
    "aspectMode": "fit"
  },
  "body": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "text",
        "text": "與你分享",
        "weight": "bold",
        "size": "xxl",
        "align": "center",
        "contents": []
      }
    ]
  },
  "footer": {
    "type": "box",
    "layout": "horizontal",
    "contents": [
      {
        "type": "button",
        "action": {
          "type": "uri",
          "label": "點我看rick roll👈",
          "uri": "https://www.youtube.com/watch?v=dQw4w9WgXcQ&pp=ygUJcmljayByb2xs"
        }
      }
    ]
  }
})])
    return 'OK',200
if(__name__ == "__main__"):
    app.run(port=2315)

# %%
from flask import Flask,request
#https://github.com/line/line-bot-sdk-python
from linebot import LineBotApi,WebhookHandler
from linebot.models import FlexSendMessage,TextSendMessage,ImageSendMessage
import json
token="5pkSnrKNYWiH82Jxc9Z4XxyT+pVmrVfMYiyjY+mDyuADpCrpa4HgmbNEdnFvWqrh2CDkCjbfLUl1O14KDwj6IpuoVfPa+oSU3pbefHzwML+qtKXj5iQ3YiBEsJSfNhW0ckXjRNye6s9ps1hDCMWA7QdB04t89/1O/w1cDnyilFU="
app=Flask(__name__)
# LINE 聊天機器人的基本資料
line_bot=LineBotApi(token)
true=True
nahida=0
furina=0
@app.route("/", methods=['POST'])
def verify():
    global nahida,furina
    data=request.get_json()
    print(data)
    #給Webhook驗證使用
    if(len(data['events'])==0):
        print("webhook驗證通知")
        pass
    elif(data["events"][0]["type"]=="message"):
        text=data["events"][0]["message"]["text"]
        uid=data["events"][0]["source"]["userId"]
        rptk=data["events"][0]["replyToken"]
        if(text=="查看比例"):
            print("check")
            line_bot.reply_message(rptk,[TextSendMessage(text="納西妲"+str(nahida/(nahida+furina)*100)+"%("+str(nahida)+")：芙寧娜"+str(furina/(nahida+furina)*100)+"%("+str(furina)+")")])
        elif(text=="我要納西妲"):
            print("nahida")
            nahida+=1
            line_bot.reply_message(rptk,[TextSendMessage(text="感謝選擇小草神，你對她的愛她全都看見囉\nhttps://genshin-impact.fandom.com/wiki/Nahida")])
        elif(text=="我要芙寧娜"):
            print("furina")
            furina+=1
            line_bot.reply_message(rptk,[TextSendMessage(text="芙寧娜還沒登場呢，因為你沒有選擇小草神，她很傷心，不會再把知識與你分享了\nhttps://genshin-impact.fandom.com/wiki/Furina")])
        else:
            print("flex")
            line_bot.reply_message(rptk,[FlexSendMessage(alt_text="123",contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "你已被小吉祥草王掐住，給我二選一哦",
            "weight": "bold",
            "size": "3xl",
            "align": "center",
            "wrap": true,
            "contents": []
          }
        ]
      },
      "hero": {
        "type": "image",
        "url": "https://i.imgur.com/I2jKwd4.jpg",
        "size": "full",
        "aspectRatio": "1.51:1",
        "aspectMode": "fit"
      },
      "body": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "查看比例",
              "text": "查看比例"
            }
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "納西妲",
              "text": "我要納西妲"
            }
          },
          {
            "type": "separator"
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "芙寧娜",
              "text": "我要芙寧娜"
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "選項在這裡",
            "weight": "bold",
            "size": "xxl",
            "align": "center",
            "contents": []
          }
        ]
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "納西妲",
            "size": "xl",
            "align": "center",
            "contents": []
          },
          {
            "type": "image",
            "url": "https://i.imgur.com/4RK5DD0.jpg",
            "size": "full"
          },
          {
            "type": "text",
            "text": "芙寧娜",
            "size": "xl",
            "align": "center",
            "contents": []
          },
          {
            "type": "image",
            "url": "https://i.imgur.com/H7sWNoS.jpg",
            "size": "full"
          }
        ]
      }
    }
  ]
})])
    return 'OK',200
if(__name__ == "__main__"):
    app.run(port=2315)

# %%
from flask import Flask,request
#https://github.com/line/line-bot-sdk-python
from linebot import LineBotApi,WebhookHandler
from linebot.models import FlexSendMessage,TextSendMessage,ImageSendMessage
import json
token="5pkSnrKNYWiH82Jxc9Z4XxyT+pVmrVfMYiyjY+mDyuADpCrpa4HgmbNEdnFvWqrh2CDkCjbfLUl1O14KDwj6IpuoVfPa+oSU3pbefHzwML+qtKXj5iQ3YiBEsJSfNhW0ckXjRNye6s9ps1hDCMWA7QdB04t89/1O/w1cDnyilFU="
app=Flask(__name__)
# LINE 聊天機器人的基本資料
line_bot=LineBotApi(token)
true=True
venti=0
zhongli=0
raiden=0
nahida=0
@app.route("/", methods=['POST'])
def verify():
    global venti,zhongli,raiden,nahida
    data=request.get_json()
    print(data)
    #給Webhook驗證使用
    if(len(data['events'])==0):
        print("webhook驗證通知")
        pass
    elif(data["events"][0]["type"]=="message"):
        text=data["events"][0]["message"]["text"]
        uid=data["events"][0]["source"]["userId"]
        rptk=data["events"][0]["replyToken"]
        check="溫迪:"+str(venti)+" 鍾離:"+str(zhongli)+" 雷電將軍:"+str(raiden)+" 納西妲:"+str(nahida)
        if(text=="查看比例"):
            print("check")
            line_bot.reply_message(rptk,[TextSendMessage(text=check)])
        elif(text=="溫迪"):
            print("venti")
            venti+=1
            line_bot.reply_message(rptk,[TextSendMessage(text="已選：溫迪")])
        elif(text=="鍾離"):
            print("zhongli")
            zhongli+=1
            line_bot.reply_message(rptk,[TextSendMessage(text="已選：鍾離")])
        elif(text=="雷電將軍"):
            print("raiden")
            raiden+=1
            line_bot.reply_message(rptk,[TextSendMessage(text="已選：雷電將軍")])
        elif(text=="納西妲"):
            print("nahida")
            nahida+=1
            line_bot.reply_message(rptk,[TextSendMessage(text="已選：納西妲")])
        else:
            print("flex")
            line_bot.reply_message(rptk,[FlexSendMessage(alt_text="123",contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "size": "micro",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "風神：溫迪 ",
            "weight": "bold",
            "align": "center",
            "contents": []
          }
        ]
      },
      "hero": {
        "type": "image",
        "url": "https://i.imgur.com/IGMAL3H.jpg",
        "size": "full",
        "aspectRatio": "1.51:1",
        "aspectMode": "fit"
      },
      "footer": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "投他一票",
              "text": "溫迪"
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "size": "micro",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "岩神：鍾離",
            "weight": "bold",
            "align": "center",
            "contents": []
          }
        ]
      },
      "hero": {
        "type": "image",
        "url": "https://i.imgur.com/7lkY36a.jpg",
        "size": "full",
        "aspectRatio": "1.51:1",
        "aspectMode": "fit"
      },
      "footer": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "投他一票",
              "text": "鍾離"
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "size": "micro",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "雷神：雷電將軍",
            "weight": "bold",
            "align": "center",
            "contents": []
          }
        ]
      },
      "hero": {
        "type": "image",
        "url": "https://i.imgur.com/XYSe0Dk.jpg",
        "size": "full",
        "aspectRatio": "1.51:1",
        "aspectMode": "fit"
      },
      "footer": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "投她一票",
              "text": "雷電將軍"
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "size": "micro",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "草神：納西妲",
            "weight": "bold",
            "align": "center",
            "contents": []
          }
        ]
      },
      "hero": {
        "type": "image",
        "url": "https://i.imgur.com/eduHc7v.jpg",
        "size": "full",
        "aspectRatio": "1.51:1",
        "aspectMode": "fit"
      },
      "footer": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "投她一票",
              "text": "納西妲"
            }
          }
        ]
      }
    }
  ]
})])
    return 'OK',200
if(__name__ == "__main__"):
    app.run(port=2315)

# %%
from flask import Flask,request
#https://github.com/line/line-bot-sdk-python
from linebot import LineBotApi,WebhookHandler
from linebot.models import FlexSendMessage,TextSendMessage,ImageSendMessage
import json
token="5pkSnrKNYWiH82Jxc9Z4XxyT+pVmrVfMYiyjY+mDyuADpCrpa4HgmbNEdnFvWqrh2CDkCjbfLUl1O14KDwj6IpuoVfPa+oSU3pbefHzwML+qtKXj5iQ3YiBEsJSfNhW0ckXjRNye6s9ps1hDCMWA7QdB04t89/1O/w1cDnyilFU="
app=Flask(__name__)
# LINE 聊天機器人的基本資料
line_bot=LineBotApi(token)
true=True
fill=["1","2","3","4","5","6","7","8","9"]
turn=0
@app.route("/", methods=['POST'])
def verify():
    global fill,turn
    data=request.get_json()
    print(data)
    #給Webhook驗證使用
    if(len(data['events'])==0):
        print("webhook驗證通知")
        pass
    elif(data["events"][0]["type"]=="message"):
        text=data["events"][0]["message"]["text"]
        uid=data["events"][0]["source"]["userId"]
        rptk=data["events"][0]["replyToken"]
        for i in fill:
            if(text==i):
                print(i)
                line_bot.reply_message(rptk,[TextSendMessage(text="已選："+i)])
                if(turn%2==0):
                    fill[int(text)-1]="O"
                else:
                    fill[int(text)-1]="X"
                turn+=1
        if(text=="reset"):
            print("reset")
            fill=["1","2","3","4","5","6","7","8","9"]
            line_bot.reply_message(rptk,[TextSendMessage(text="RESET")])
        else:
            print("flex")
            line_bot.reply_message(rptk,[FlexSendMessage(alt_text="123",contents={
  "type": "bubble",
  "direction": "ltr",
  "header": {
    "type": "box",
    "layout": "horizontal",
    "contents": [
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": fill[0],
          "text": "1"
        }
      },
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": fill[1],
          "text": "2"
        }
      },
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": fill[2],
          "text": "3"
        }
      }
    ]
  },
  "body": {
    "type": "box",
    "layout": "horizontal",
    "contents": [
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": fill[3],
          "text": "4"
        }
      },
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": fill[4],
          "text": "5"
        }
      },
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": fill[5],
          "text": "6"
        }
      }
    ]
  },
  "footer": {
    "type": "box",
    "layout": "horizontal",
    "contents": [
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": fill[6],
          "text": "7"
        }
      },
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": fill[7],
          "text": "8"
        }
      },
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": fill[8],
          "text": "9"
        }
      }
    ]
  }
})])
    return 'OK',200
if(__name__ == "__main__"):
    app.run(port=2315)

# %%
pip install pyimgur

# %%
import pyimgur
clientid="f64d00bc4ff6cbc"
title="Uploaded with PyImgur"
im=pyimgur.Imgur(clientid)
uploaded_image=im.upload_image("C://Users//User//Downloads//nahidaskill.jpg",title=title)
print(uploaded_image.title)
print(uploaded_image.link)
print(uploaded_image.type)

# %%
#nahida swing: https://i.imgur.com/EikhyBv.png
#nahida punch: https://i.imgur.com/I2jKwd4.jpg
#nahida pv: https://i.imgur.com/4RK5DD0.jpg
#furina pv: https://i.imgur.com/H7sWNoS.jpg
#nahida skill: https://i.imgur.com/Dd8ZC0d.jpg
