# %%
# pip install pymongo

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://yongenyang:steven4716@databasecluster.odga2e4.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://yongenyang:steven4716@databasecluster.odga2e4.mongodb.net/?retryWrites=true&w=majority"

client = MongoClient(uri, server_api=ServerApi('1'))
db=client["sample_mflix"]
col=db.comments
result=col.find_one({"name":"John Bishop"})
print(result["text"])
# Out:
# Id error ab at molestias dolorum incidunt. Non deserunt praesentium dolorem nihil. Optio tempora vel ut quas.
# Minus dicta numquam quasi. Rem totam cumque at eum. Ullam hic ut ea magni.

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://yongenyang:steven4716@databasecluster.odga2e4.mongodb.net/?retryWrites=true&w=majority"

client = MongoClient(uri, server_api=ServerApi('1'))
db=client["sample_mflix"]
col=db.movies
result=list(col.find({"year":2004}))
for i in result:
    print(i["title"])
# Out:
# Bluebird
# Hellboy
# Il resto di niente
# Kebab Connection
# Olga
# Exorcist: The Beginning
# 2046
# Vanity Fair
# Surviving Christmas
# The Girl Next Door
# Addictions and Subtractions
# Superbabies: Baby Geniuses 2
# The Beautiful Country
# Renegade
# The Butterfly Effect
# The Dark Diamond
# Meet the Fockers
# The Phantom of the Opera
# The Chronicles of Riddick
# Mindhunters
# Purgatory House
# Shrek 2
# Home on the Range
# Jersey Girl
# The Holy Girl
# The Conscientious Objector
# Harry Potter and the Prisoner of Azkaban
# Long Dark Night
# Shark Tale
# Finding Neverland
# The Blue Butterfly
# Immortal (Ad Vitam)
# Finding Neverland
# The Perfect Score
# Popular Music
# Benji: Off the Leash!
# Twisted
# Spider-Man 2
# Taxi
# Thunderstruck
# One Point O
# Bridget Jones: The Edge of Reason
# Hidalgo
# The Incredibles
# The Lion King 1 1/2
# The Motorcycle Diaries
# Cazuza: Time Doesn't Stop
# Resident Evil: Apocalypse
# The Alamo
# The Day After Tomorrow
# ...

# %%
import requests
from bs4 import BeautifulSoup
from time import sleep
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

url104=requests.get("https://www.104.com.tw/jobs/search/?ro=0&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A%E5%88%86%E6%9E%90%E5%B8%AB&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&page=1&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1")
soup104=BeautifulSoup(url104.text)
page=1

uri = "mongodb+srv://yongenyang:steven4716@databasecluster.odga2e4.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(uri, server_api=ServerApi('1'))
db=client["104職缺清單"]
col=db.big_data

while(soup104.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item")):
    print("\n第%d頁\n------------------------\n"%(page))
    for i in soup104.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item"):
        print("職稱： "+i.a.text)
        print("網址： https:"+i.a["href"])
        print("公司： "+i.ul.a.text[:-20],end="")
        print("地區： "+i.select("ul")[1].li.text)
        if(i.select("div")[4].select("span")!=[])and(i.select("div")[4].span.text=="待遇面議"):
            job={
                "職稱":i.a.text,
                "網址":"https:"+i.a["href"],
                "公司":i.ul.a.text[:-20],
                "地區":i.select("ul")[1].li.text,
                "薪資":i.select("div")[4].span.text
            }
            print("薪資： "+i.select("div")[4].span.text)
        else:
            job={
                "職稱":i.a.text,
                "網址":"https:"+i.a["href"],
                "公司":i.ul.a.text[:-20],
                "地區":i.select("ul")[1].li.text,
                "薪資":i.select("div")[4].a.text
            }
            print("薪資： "+i.select("div")[4].a.text)
        col.insert_one(job)
        print("")
    page+=1
    url104=requests.get("https://www.104.com.tw/jobs/search/?ro=0&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&page="+str(page)+"&mode=s&jobsource=tab_cs_to_job&langFlag=0&langStatus=0&recommendJob=1&hotJob=1")
    soup104=BeautifulSoup(url104.text)
    sleep(2)
# Out:
# 第1頁
# ------------------------
#
# 職稱： 大數據分析師
# 網址： https://www.104.com.tw/job/7ykod?jobsource=jolist_c_relevance
# 公司： 中嘉數位股份有限公司
# 地區： 台北市內湖區
# 薪資： 待遇面議
#
# 職稱： 資深數據分析師 Senior Data Analyst
# 網址： https://www.104.com.tw/job/838wl?jobsource=jolist_c_relevance
# 公司： Gogolook_走著瞧股份有限公司
# 地區： 台北市中正區
# 薪資： 待遇面議
#
# 職稱： 大數據分析師
# 網址： https://www.104.com.tw/job/337bp?jobsource=jolist_c_relevance
# 公司： TutorABC_麥奇數位股份有限公司
# 地區： 台北市中正區
# 薪資： 待遇面議
#
# 職稱： 數據分析師
# 網址： https://www.104.com.tw/job/82hof?jobsource=jolist_c_relevance
# 公司： 黛莉貝爾有限公司
# 地區： 高雄市三民區
# 薪資： 月薪38,100元
#
# 職稱： AI大數據分析師
# 網址： https://www.104.com.tw/job/82oh0?jobsource=jolist_c_relevance
# 公司： 網威智慧科技股份有限公司
# 地區： 台北市內湖區
# 薪資： 年薪500,000元以上
#
# 職稱： 數據師、大數據分析師(臺北市信義區)
# 網址： https://www.104.com.tw/job/7cfoj?jobsource=jolist_c_relevance
# 公司： 鼎漢國際工程顧問股份有限公司
# 地區： 台北市信義區
# 薪資： 月薪30,000~50,000元
#
# 職稱： 數據分析師
# 網址： https://www.104.com.tw/job/82b45?jobsource=jolist_c_relevance
# 公司： 大極科技有限公司
# 地區： 台北市南港區
# 薪資： 待遇面議
#
# ...
